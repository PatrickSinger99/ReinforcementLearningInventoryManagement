# %% [markdown]
# ### 1. Imports

# %%
# Import libraries
import gym
import numpy as np
from stable_baselines.common.policies import MlpPolicy
from stable_baselines import PPO2, A2C
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# c:\users\patri\documents\github\reinforcementlearninginventorymanagement\venv_37\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
# Import classes
from rl_environment import Environment

# %% [markdown]
# ### Environment creation

# %%
# Parameters
number_of_regional_warehouses = 1
max_inventory_amount_regional_warehouses = 40
max_inventory_amount_central_warehouse = 100
customer_demand = 1
simulation_length = 30
lead_time = 4

# %%
env = Environment(number_of_regional_wh = number_of_regional_warehouses, 
                  rw_inventory_limit = max_inventory_amount_regional_warehouses, 
                  cw_inventory_limit = max_inventory_amount_central_warehouse,
                  demand = customer_demand,
                  sim_length = simulation_length,
                  lead_time = lead_time)
# Out:
# Simulation created with the following parameters:
# ------------------------------------------------------------
# central_warehouse ; Inventory: 33
# regional_warehouse_2 ; ID: 1 ; Inventory: 13 ; Demand: 1 ; Lost sales: 0
# ------------------------------------------------------------

# %% [markdown]
# ### RL model training

# %% [markdown]
# ###### Model 1: PPO
# Proximal Policy Optimization
# https://openai.com/blog/openai-baselines-ppo/

# %%
ppo_model = PPO2(MlpPolicy, env, verbose=1)
ppo_model.learn(total_timesteps=30000)
# Out:
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 4.8937877e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.12         |
# | fps                | 509           |
# | n_updates          | 1             |
# | policy_entropy     | 0.693136      |
# | policy_loss        | -0.0007821121 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 0.072028935   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.3614601e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.819        |
# | fps                | 1256          |
# | n_updates          | 2             |
# | policy_entropy     | 0.6931186     |
# | policy_loss        | -0.0003559636 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.251         |
# | total_timesteps    | 256           |
# | value_loss         | 0.07388423    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.201513e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.412        |
# | fps                | 1403          |
# | n_updates          | 3             |
# | policy_entropy     | 0.69311816    |
# | policy_loss        | -0.0012183954 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.354         |
# | total_timesteps    | 384           |
# | value_loss         | 0.037820995   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 9.452509e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.26          |
# | fps                | 1116           |
# | n_updates          | 4              |
# | policy_entropy     | 0.6930827      |
# | policy_loss        | -7.7481265e-05 |
# | serial_timesteps   | 512            |
# | time_elapsed       | 0.446          |
# | total_timesteps    | 512            |
# | value_loss         | 0.04865423     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.3727049e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.167         |
# | fps                | 968           |
# | n_updates          | 5             |
# | policy_entropy     | 0.6930633     |
# | policy_loss        | -0.0003722367 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 0.563         |
# | total_timesteps    | 640           |
# | value_loss         | 0.023324223   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.1696827e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.274         |
# | fps                | 1300          |
# | n_updates          | 6             |
# | policy_entropy     | 0.6929944     |
# | policy_loss        | -0.0002760879 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 0.696         |
# | total_timesteps    | 768           |
# | value_loss         | 0.015170481   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.555801e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.304         |
# | fps                | 1571          |
# | n_updates          | 7             |
# | policy_entropy     | 0.6929718     |
# | policy_loss        | -0.0005065747 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 0.795         |
# | total_timesteps    | 896           |
# | value_loss         | 0.03204474    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.908295e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.487         |
# | fps                | 1533          |
# | n_updates          | 8             |
# | policy_entropy     | 0.69299257    |
# | policy_loss        | -0.0001372965 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 0.876         |
# | total_timesteps    | 1024          |
# | value_loss         | 0.016708639   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.5394537e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.247         |
# | fps                | 1265          |
# | n_updates          | 9             |
# | policy_entropy     | 0.69306487    |
# | policy_loss        | -0.0005858862 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 0.96          |
# | total_timesteps    | 1152          |
# | value_loss         | 0.04742737    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 9.974191e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.464          |
# | fps                | 1296           |
# | n_updates          | 10             |
# | policy_entropy     | 0.69298196     |
# | policy_loss        | -0.00075249525 |
# | serial_timesteps   | 1280           |
# | time_elapsed       | 1.06           |
# | total_timesteps    | 1280           |
# | value_loss         | 0.014637219    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.3910444e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.487         |
# | fps                | 1534          |
# | n_updates          | 11            |
# | policy_entropy     | 0.6928378     |
# | policy_loss        | 8.943293e-05  |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 1.16          |
# | total_timesteps    | 1408          |
# | value_loss         | 0.01442799    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.125056e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.554         |
# | fps                | 1498          |
# | n_updates          | 12            |
# | policy_entropy     | 0.692909      |
# | policy_loss        | -0.0010965661 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 1.24          |
# | total_timesteps    | 1536          |
# | value_loss         | 0.028233401   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.5463576e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.466         |
# | fps                | 1555          |
# | n_updates          | 13            |
# | policy_entropy     | 0.6928052     |
# | policy_loss        | -0.0010556667 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 1.34          |
# | total_timesteps    | 1664          |
# | value_loss         | 0.028572487   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.2185003e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.6            |
# | fps                | 1537           |
# | n_updates          | 14             |
# | policy_entropy     | 0.69264776     |
# | policy_loss        | -0.00044800178 |
# | serial_timesteps   | 1792           |
# | time_elapsed       | 1.43           |
# | total_timesteps    | 1792           |
# | value_loss         | 0.021421064    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.419312e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.543         |
# | fps                | 1265          |
# | n_updates          | 15            |
# | policy_entropy     | 0.6924535     |
# | policy_loss        | -0.0008497634 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 1.51          |
# | total_timesteps    | 1920          |
# | value_loss         | 0.018407073   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 2.129453e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.625        |
# | fps                | 1519         |
# | n_updates          | 16           |
# | policy_entropy     | 0.6922759    |
# | policy_loss        | -0.000729296 |
# | serial_timesteps   | 2048         |
# | time_elapsed       | 1.61         |
# | total_timesteps    | 2048         |
# | value_loss         | 0.014856761  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 2.3336743e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.524         |
# | fps                | 1533          |
# | n_updates          | 17            |
# | policy_entropy     | 0.69211286    |
# | policy_loss        | -0.0013774489 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 1.69          |
# | total_timesteps    | 2176          |
# | value_loss         | 0.016189732   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.8985547e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.636         |
# | fps                | 1297          |
# | n_updates          | 18            |
# | policy_entropy     | 0.6912929     |
# | policy_loss        | -0.000920894  |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 1.78          |
# | total_timesteps    | 2304          |
# | value_loss         | 0.016827656   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.7801327e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.55           |
# | fps                | 1554           |
# | n_updates          | 19             |
# | policy_entropy     | 0.6911529      |
# | policy_loss        | -0.00056647474 |
# | serial_timesteps   | 2432           |
# | time_elapsed       | 1.88           |
# | total_timesteps    | 2432           |
# | value_loss         | 0.018093413    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.4054667e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.419         |
# | fps                | 1534          |
# | n_updates          | 20            |
# | policy_entropy     | 0.6910185     |
# | policy_loss        | -0.0006451232 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 1.96          |
# | total_timesteps    | 2560          |
# | value_loss         | 0.03437678    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.845153e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.421         |
# | fps                | 1534          |
# | n_updates          | 21            |
# | policy_entropy     | 0.6907087     |
# | policy_loss        | -0.0009535438 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 2.04          |
# | total_timesteps    | 2688          |
# | value_loss         | 0.015165116   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.8468192e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.614          |
# | fps                | 1293           |
# | n_updates          | 22             |
# | policy_entropy     | 0.68938464     |
# | policy_loss        | -0.00071997044 |
# | serial_timesteps   | 2816           |
# | time_elapsed       | 2.13           |
# | total_timesteps    | 2816           |
# | value_loss         | 0.017699769    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.8759467e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.61          |
# | fps                | 1517          |
# | n_updates          | 23            |
# | policy_entropy     | 0.68811905    |
# | policy_loss        | -0.0014656787 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 2.22          |
# | total_timesteps    | 2944          |
# | value_loss         | 0.017029999   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.970159e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.638         |
# | fps                | 1536          |
# | n_updates          | 24            |
# | policy_entropy     | 0.68808645    |
# | policy_loss        | -0.0006085234 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 2.31          |
# | total_timesteps    | 3072          |
# | value_loss         | 0.012095201   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 6.684118e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.449        |
# | fps                | 1292         |
# | n_updates          | 25           |
# | policy_entropy     | 0.6856203    |
# | policy_loss        | -0.002116014 |
# | serial_timesteps   | 3200         |
# | time_elapsed       | 2.39         |
# | total_timesteps    | 3200         |
# | value_loss         | 0.032762032  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00020945785 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.586         |
# | fps                | 1461          |
# | n_updates          | 26            |
# | policy_entropy     | 0.6829156     |
# | policy_loss        | -0.0035997708 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 2.49          |
# | total_timesteps    | 3328          |
# | value_loss         | 0.019022614   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011841563 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.589         |
# | fps                | 1599          |
# | n_updates          | 27            |
# | policy_entropy     | 0.6800698     |
# | policy_loss        | -0.0012177888 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 2.58          |
# | total_timesteps    | 3456          |
# | value_loss         | 0.027603082   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00033663952 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.577         |
# | fps                | 1535          |
# | n_updates          | 28            |
# | policy_entropy     | 0.6693347     |
# | policy_loss        | -0.0054912246 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 2.66          |
# | total_timesteps    | 3584          |
# | value_loss         | 0.03464207    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00049300026 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.522         |
# | fps                | 1492          |
# | n_updates          | 29            |
# | policy_entropy     | 0.65816504    |
# | policy_loss        | -0.0040021446 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 2.74          |
# | total_timesteps    | 3712          |
# | value_loss         | 0.05097065    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00035007385 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.52          |
# | fps                | 1313          |
# | n_updates          | 30            |
# | policy_entropy     | 0.64160764    |
# | policy_loss        | -0.0033682778 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 2.83          |
# | total_timesteps    | 3840          |
# | value_loss         | 0.035288177   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019520317 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.575         |
# | fps                | 1535          |
# | n_updates          | 31            |
# | policy_entropy     | 0.62446934    |
# | policy_loss        | -0.0016335747 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 2.93          |
# | total_timesteps    | 3968          |
# | value_loss         | 0.04044524    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001874682  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.25          |
# | fps                | 1535          |
# | n_updates          | 32            |
# | policy_entropy     | 0.61278033    |
# | policy_loss        | -0.0037163815 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 3.01          |
# | total_timesteps    | 4096          |
# | value_loss         | 0.13250612    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020257794 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.668         |
# | fps                | 1422          |
# | n_updates          | 33            |
# | policy_entropy     | 0.601312      |
# | policy_loss        | -0.0032156194 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 3.09          |
# | total_timesteps    | 4224          |
# | value_loss         | 0.060315836   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.6715686e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.15          |
# | fps                | 1363          |
# | n_updates          | 34            |
# | policy_entropy     | 0.5904606     |
# | policy_loss        | -0.0018986446 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 3.18          |
# | total_timesteps    | 4352          |
# | value_loss         | 0.123595096   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00046074277 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.187         |
# | fps                | 1527          |
# | n_updates          | 35            |
# | policy_entropy     | 0.5693523     |
# | policy_loss        | -0.0045876927 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 3.28          |
# | total_timesteps    | 4480          |
# | value_loss         | 0.1228664     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.826445e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0781         |
# | fps                | 1313           |
# | n_updates          | 36             |
# | policy_entropy     | 0.5513649      |
# | policy_loss        | 0.000118587865 |
# | serial_timesteps   | 4608           |
# | time_elapsed       | 3.36           |
# | total_timesteps    | 4608           |
# | value_loss         | 0.1308429      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00027374167 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.423         |
# | fps                | 1299          |
# | n_updates          | 37            |
# | policy_entropy     | 0.5517646     |
# | policy_loss        | -0.003939459  |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 3.46          |
# | total_timesteps    | 4736          |
# | value_loss         | 0.14046738    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0018955641 |
# | clipfrac           | 0.00390625   |
# | explained_variance | 0.143        |
# | fps                | 1106         |
# | n_updates          | 38           |
# | policy_entropy     | 0.5062144    |
# | policy_loss        | -0.008961921 |
# | serial_timesteps   | 4864         |
# | time_elapsed       | 3.56         |
# | total_timesteps    | 4864         |
# | value_loss         | 0.12742773   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0025053932 |
# | clipfrac           | 0.025390625  |
# | explained_variance | 0.353        |
# | fps                | 1130         |
# | n_updates          | 39           |
# | policy_entropy     | 0.45487455   |
# | policy_loss        | -0.016010003 |
# | serial_timesteps   | 4992         |
# | time_elapsed       | 3.67         |
# | total_timesteps    | 4992         |
# | value_loss         | 0.17509444   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.000833869   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0633       |
# | fps                | 1220          |
# | n_updates          | 40            |
# | policy_entropy     | 0.40514553    |
# | policy_loss        | -0.0014599303 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 3.79          |
# | total_timesteps    | 5120          |
# | value_loss         | 0.23391771    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.145924e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.274         |
# | fps                | 897           |
# | n_updates          | 41            |
# | policy_entropy     | 0.3982984     |
# | policy_loss        | -0.0029491675 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 3.89          |
# | total_timesteps    | 5248          |
# | value_loss         | 0.2074146     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00043496673 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.067         |
# | fps                | 867           |
# | n_updates          | 42            |
# | policy_entropy     | 0.43299243    |
# | policy_loss        | -0.003510159  |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 4.04          |
# | total_timesteps    | 5376          |
# | value_loss         | 0.22864161    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.0047674e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.2           |
# | fps                | 1199          |
# | n_updates          | 43            |
# | policy_entropy     | 0.4378683     |
# | policy_loss        | -0.0013272145 |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 4.19          |
# | total_timesteps    | 5504          |
# | value_loss         | 0.29030082    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013109927 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.222         |
# | fps                | 1219          |
# | n_updates          | 44            |
# | policy_entropy     | 0.41503462    |
# | policy_loss        | -0.0007914363 |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 4.29          |
# | total_timesteps    | 5632          |
# | value_loss         | 0.23564136    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002895507  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0909        |
# | fps                | 1283          |
# | n_updates          | 45            |
# | policy_entropy     | 0.41441563    |
# | policy_loss        | -0.0043949233 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 4.4           |
# | total_timesteps    | 5760          |
# | value_loss         | 0.32004583    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0008293875 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.198        |
# | fps                | 1309         |
# | n_updates          | 46           |
# | policy_entropy     | 0.40626413   |
# | policy_loss        | -0.00567663  |
# | serial_timesteps   | 5888         |
# | time_elapsed       | 4.5          |
# | total_timesteps    | 5888         |
# | value_loss         | 0.27510005   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00019455717 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.407         |
# | fps                | 1246          |
# | n_updates          | 47            |
# | policy_entropy     | 0.37116396    |
# | policy_loss        | -0.000903044  |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 4.6           |
# | total_timesteps    | 6016          |
# | value_loss         | 0.32319328    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.709985e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.275         |
# | fps                | 1431          |
# | n_updates          | 48            |
# | policy_entropy     | 0.36578655    |
# | policy_loss        | -0.0030139482 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 4.7           |
# | total_timesteps    | 6144          |
# | value_loss         | 2.211075      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023706295 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.263         |
# | fps                | 1555          |
# | n_updates          | 49            |
# | policy_entropy     | 0.3889404     |
# | policy_loss        | -0.002302751  |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 4.79          |
# | total_timesteps    | 6272          |
# | value_loss         | 6.165384      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00020108813  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.358          |
# | fps                | 1513           |
# | n_updates          | 50             |
# | policy_entropy     | 0.40611959     |
# | policy_loss        | -0.00041070383 |
# | serial_timesteps   | 6400           |
# | time_elapsed       | 4.88           |
# | total_timesteps    | 6400           |
# | value_loss         | 1.0669312      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.000102945785 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.209          |
# | fps                | 1540           |
# | n_updates          | 51             |
# | policy_entropy     | 0.43230247     |
# | policy_loss        | -0.0024969229  |
# | serial_timesteps   | 6528           |
# | time_elapsed       | 4.96           |
# | total_timesteps    | 6528           |
# | value_loss         | 0.36979997     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.1221846e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.32          |
# | fps                | 1523          |
# | n_updates          | 52            |
# | policy_entropy     | 0.4327804     |
# | policy_loss        | -0.001989103  |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 5.04          |
# | total_timesteps    | 6656          |
# | value_loss         | 0.48860615    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.098144e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.125         |
# | fps                | 1568          |
# | n_updates          | 53            |
# | policy_entropy     | 0.42636144    |
# | policy_loss        | -0.0013482161 |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 5.13          |
# | total_timesteps    | 6784          |
# | value_loss         | 0.3907088     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.135818e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.374         |
# | fps                | 1278          |
# | n_updates          | 54            |
# | policy_entropy     | 0.43612528    |
# | policy_loss        | -0.0018148086 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 5.21          |
# | total_timesteps    | 6912          |
# | value_loss         | 1.8591267     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.665195e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.138         |
# | fps                | 1539          |
# | n_updates          | 55            |
# | policy_entropy     | 0.42122582    |
# | policy_loss        | -0.0018516546 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 5.31          |
# | total_timesteps    | 7040          |
# | value_loss         | 0.33203813    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010377777 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.106         |
# | fps                | 1536          |
# | n_updates          | 56            |
# | policy_entropy     | 0.41143918    |
# | policy_loss        | -0.0019525932 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 5.39          |
# | total_timesteps    | 7168          |
# | value_loss         | 0.32860243    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.2559448e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.373         |
# | fps                | 1536          |
# | n_updates          | 57            |
# | policy_entropy     | 0.387949      |
# | policy_loss        | 0.0015108733  |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 5.48          |
# | total_timesteps    | 7296          |
# | value_loss         | 3.970592      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.4027757e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0766       |
# | fps                | 1535          |
# | n_updates          | 58            |
# | policy_entropy     | 0.40857828    |
# | policy_loss        | -0.0009968288 |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 5.56          |
# | total_timesteps    | 7424          |
# | value_loss         | 0.41153392    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024605088 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0615       |
# | fps                | 1457          |
# | n_updates          | 59            |
# | policy_entropy     | 0.41107848    |
# | policy_loss        | -0.0034030788 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 5.64          |
# | total_timesteps    | 7552          |
# | value_loss         | 0.39032322    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.2001734e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.33          |
# | fps                | 1623          |
# | n_updates          | 60            |
# | policy_entropy     | 0.38173485    |
# | policy_loss        | 0.0006491665  |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 5.73          |
# | total_timesteps    | 7680          |
# | value_loss         | 3.2520688     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.4664674e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0297        |
# | fps                | 1539          |
# | n_updates          | 61            |
# | policy_entropy     | 0.39174628    |
# | policy_loss        | -0.001230107  |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 5.81          |
# | total_timesteps    | 7808          |
# | value_loss         | 0.8440543     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.317688e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.187         |
# | fps                | 1534          |
# | n_updates          | 62            |
# | policy_entropy     | 0.43836442    |
# | policy_loss        | -0.0008283841 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 5.89          |
# | total_timesteps    | 7936          |
# | value_loss         | 0.6650421     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.1552157e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.451         |
# | fps                | 1890          |
# | n_updates          | 63            |
# | policy_entropy     | 0.41717476    |
# | policy_loss        | -0.0015134711 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 5.98          |
# | total_timesteps    | 8064          |
# | value_loss         | 1.4917737     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003076126 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.429        |
# | fps                | 1820         |
# | n_updates          | 64           |
# | policy_entropy     | 0.42204416   |
# | policy_loss        | -0.004525097 |
# | serial_timesteps   | 8192         |
# | time_elapsed       | 6.06         |
# | total_timesteps    | 8192         |
# | value_loss         | 0.93548095   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00011510485 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0344        |
# | fps                | 1328          |
# | n_updates          | 65            |
# | policy_entropy     | 0.43976834    |
# | policy_loss        | 0.00018748152 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 6.13          |
# | total_timesteps    | 8320          |
# | value_loss         | 0.5506124     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012059511 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.393         |
# | fps                | 1536          |
# | n_updates          | 66            |
# | policy_entropy     | 0.4619216     |
# | policy_loss        | -0.0018994492 |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 6.23          |
# | total_timesteps    | 8448          |
# | value_loss         | 1.0665934     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.078741e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0654       |
# | fps                | 1534          |
# | n_updates          | 67            |
# | policy_entropy     | 0.44063827    |
# | policy_loss        | -0.0024776966 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 6.31          |
# | total_timesteps    | 8576          |
# | value_loss         | 0.5567206     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.8516733e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.16           |
# | fps                | 1538           |
# | n_updates          | 68             |
# | policy_entropy     | 0.47028938     |
# | policy_loss        | -0.00053875125 |
# | serial_timesteps   | 8704           |
# | time_elapsed       | 6.39           |
# | total_timesteps    | 8704           |
# | value_loss         | 0.51897144     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00048601071 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0484        |
# | fps                | 1535          |
# | n_updates          | 69            |
# | policy_entropy     | 0.45302907    |
# | policy_loss        | -0.0049982443 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 6.48          |
# | total_timesteps    | 8832          |
# | value_loss         | 0.30709538    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.909664e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.149         |
# | fps                | 1534          |
# | n_updates          | 70            |
# | policy_entropy     | 0.46953064    |
# | policy_loss        | -0.0005834373 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 6.56          |
# | total_timesteps    | 8960          |
# | value_loss         | 0.35532084    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00031655678 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.106        |
# | fps                | 1536          |
# | n_updates          | 71            |
# | policy_entropy     | 0.45746914    |
# | policy_loss        | -0.0056991107 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 6.64          |
# | total_timesteps    | 9088          |
# | value_loss         | 0.6763362     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012229494 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000699     |
# | fps                | 1535          |
# | n_updates          | 72            |
# | policy_entropy     | 0.40723822    |
# | policy_loss        | -0.0010638271 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 6.73          |
# | total_timesteps    | 9216          |
# | value_loss         | 0.36228976    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003229714  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00186      |
# | fps                | 1498          |
# | n_updates          | 73            |
# | policy_entropy     | 0.4523216     |
# | policy_loss        | -0.0034042252 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 6.81          |
# | total_timesteps    | 9344          |
# | value_loss         | 0.3374484     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0006842015 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -0.03        |
# | fps                | 1557         |
# | n_updates          | 74           |
# | policy_entropy     | 0.4329103    |
# | policy_loss        | -0.002951908 |
# | serial_timesteps   | 9472         |
# | time_elapsed       | 6.89         |
# | total_timesteps    | 9472         |
# | value_loss         | 0.2679052    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 5.8846384e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.301         |
# | fps                | 1165          |
# | n_updates          | 75            |
# | policy_entropy     | 0.4747989     |
# | policy_loss        | -0.001224984  |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 6.98          |
# | total_timesteps    | 9600          |
# | value_loss         | 0.26645222    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.2955205e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.209         |
# | fps                | 1419          |
# | n_updates          | 76            |
# | policy_entropy     | 0.471458      |
# | policy_loss        | -0.0017414222 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 7.09          |
# | total_timesteps    | 9728          |
# | value_loss         | 0.26324564    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.624246e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.332          |
# | fps                | 1174           |
# | n_updates          | 77             |
# | policy_entropy     | 0.5009732      |
# | policy_loss        | -0.00016140565 |
# | serial_timesteps   | 9856           |
# | time_elapsed       | 7.18           |
# | total_timesteps    | 9856           |
# | value_loss         | 0.99068904     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.341964e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.318         |
# | fps                | 1136          |
# | n_updates          | 78            |
# | policy_entropy     | 0.48780805    |
# | policy_loss        | -0.0030172106 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 7.29          |
# | total_timesteps    | 9984          |
# | value_loss         | 2.1585674     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.2539824e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.287         |
# | fps                | 1262          |
# | n_updates          | 79            |
# | policy_entropy     | 0.46270072    |
# | policy_loss        | -0.0012432195 |
# | serial_timesteps   | 10112         |
# | time_elapsed       | 7.4           |
# | total_timesteps    | 10112         |
# | value_loss         | 0.21573065    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013145442 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.267         |
# | fps                | 1321          |
# | n_updates          | 80            |
# | policy_entropy     | 0.44919613    |
# | policy_loss        | -0.0031567235 |
# | serial_timesteps   | 10240         |
# | time_elapsed       | 7.5           |
# | total_timesteps    | 10240         |
# | value_loss         | 0.13944423    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015423531 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.124         |
# | fps                | 1190          |
# | n_updates          | 81            |
# | policy_entropy     | 0.48083514    |
# | policy_loss        | -0.0020108228 |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 7.6           |
# | total_timesteps    | 10368         |
# | value_loss         | 0.74199057    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00052492076 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.135         |
# | fps                | 1109          |
# | n_updates          | 82            |
# | policy_entropy     | 0.45747262    |
# | policy_loss        | -0.0050331    |
# | serial_timesteps   | 10496         |
# | time_elapsed       | 7.71          |
# | total_timesteps    | 10496         |
# | value_loss         | 0.34855163    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006898674  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.186         |
# | fps                | 1264          |
# | n_updates          | 83            |
# | policy_entropy     | 0.41449735    |
# | policy_loss        | -0.0048888354 |
# | serial_timesteps   | 10624         |
# | time_elapsed       | 7.83          |
# | total_timesteps    | 10624         |
# | value_loss         | 0.33752185    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024708651 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.373         |
# | fps                | 1534          |
# | n_updates          | 84            |
# | policy_entropy     | 0.41407686    |
# | policy_loss        | -0.0016273976 |
# | serial_timesteps   | 10752         |
# | time_elapsed       | 7.93          |
# | total_timesteps    | 10752         |
# | value_loss         | 1.0352958     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023926845 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.11          |
# | fps                | 1579          |
# | n_updates          | 85            |
# | policy_entropy     | 0.39825976    |
# | policy_loss        | -0.002287628  |
# | serial_timesteps   | 10880         |
# | time_elapsed       | 8.01          |
# | total_timesteps    | 10880         |
# | value_loss         | 0.76156634    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011010439 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0131       |
# | fps                | 1537          |
# | n_updates          | 86            |
# | policy_entropy     | 0.37641856    |
# | policy_loss        | -0.0012535788 |
# | serial_timesteps   | 11008         |
# | time_elapsed       | 8.09          |
# | total_timesteps    | 11008         |
# | value_loss         | 0.49461865    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.199725e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.389          |
# | fps                | 1533           |
# | n_updates          | 87             |
# | policy_entropy     | 0.3975405      |
# | policy_loss        | -0.00097046257 |
# | serial_timesteps   | 11136          |
# | time_elapsed       | 8.18           |
# | total_timesteps    | 11136          |
# | value_loss         | 2.40179        |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 9.679191e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.147        |
# | fps                | 1535         |
# | n_updates          | 88           |
# | policy_entropy     | 0.43195537   |
# | policy_loss        | -0.001686355 |
# | serial_timesteps   | 11264        |
# | time_elapsed       | 8.26         |
# | total_timesteps    | 11264        |
# | value_loss         | 0.58926386   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00038809254 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00906       |
# | fps                | 1495          |
# | n_updates          | 89            |
# | policy_entropy     | 0.37588254    |
# | policy_loss        | -0.0057249297 |
# | serial_timesteps   | 11392         |
# | time_elapsed       | 8.34          |
# | total_timesteps    | 11392         |
# | value_loss         | 0.29544815    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023286048 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.386         |
# | fps                | 1560          |
# | n_updates          | 90            |
# | policy_entropy     | 0.37924546    |
# | policy_loss        | -0.004572364  |
# | serial_timesteps   | 11520         |
# | time_elapsed       | 8.44          |
# | total_timesteps    | 11520         |
# | value_loss         | 3.349177      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.6653665e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.026        |
# | fps                | 1535          |
# | n_updates          | 91            |
# | policy_entropy     | 0.3967561     |
# | policy_loss        | -0.001720833  |
# | serial_timesteps   | 11648         |
# | time_elapsed       | 8.53          |
# | total_timesteps    | 11648         |
# | value_loss         | 0.86910224    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023432267 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0377       |
# | fps                | 1536          |
# | n_updates          | 92            |
# | policy_entropy     | 0.3722773     |
# | policy_loss        | -0.0023162584 |
# | serial_timesteps   | 11776         |
# | time_elapsed       | 8.61          |
# | total_timesteps    | 11776         |
# | value_loss         | 0.26747876    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.771707e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0864        |
# | fps                | 1280          |
# | n_updates          | 93            |
# | policy_entropy     | 0.3917652     |
# | policy_loss        | -0.0007931865 |
# | serial_timesteps   | 11904         |
# | time_elapsed       | 8.69          |
# | total_timesteps    | 11904         |
# | value_loss         | 0.43375722    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002692604  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.319         |
# | fps                | 1535          |
# | n_updates          | 94            |
# | policy_entropy     | 0.41421077    |
# | policy_loss        | -0.0025131672 |
# | serial_timesteps   | 12032         |
# | time_elapsed       | 8.79          |
# | total_timesteps    | 12032         |
# | value_loss         | 0.9196279     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016237976 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0403        |
# | fps                | 1508          |
# | n_updates          | 95            |
# ...
# | total_timesteps    | 25984          |
# | value_loss         | 0.85250556     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0001209105   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0515        |
# | fps                | 1562           |
# | n_updates          | 204            |
# | policy_entropy     | 0.110831045    |
# | policy_loss        | -3.4661498e-06 |
# | serial_timesteps   | 26112          |
# | time_elapsed       | 18.3           |
# | total_timesteps    | 26112          |
# | value_loss         | 1.2536744      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.437671e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0685        |
# | fps                | 1536           |
# | n_updates          | 205            |
# | policy_entropy     | 0.12755369     |
# | policy_loss        | -6.4834254e-05 |
# | serial_timesteps   | 26240          |
# | time_elapsed       | 18.4           |
# | total_timesteps    | 26240          |
# | value_loss         | 1.2106018      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.9507532e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00276      |
# | fps                | 1535          |
# | n_updates          | 206           |
# | policy_entropy     | 0.14080903    |
# | policy_loss        | -0.0008216505 |
# | serial_timesteps   | 26368         |
# | time_elapsed       | 18.5          |
# | total_timesteps    | 26368         |
# | value_loss         | 1.6415855     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003586485  |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.00613       |
# | fps                | 1293          |
# | n_updates          | 207           |
# | policy_entropy     | 0.12237201    |
# | policy_loss        | -0.0030961859 |
# | serial_timesteps   | 26496         |
# | time_elapsed       | 18.5          |
# | total_timesteps    | 26496         |
# | value_loss         | 1.2671301     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017573079 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0363        |
# | fps                | 1500          |
# | n_updates          | 208           |
# | policy_entropy     | 0.13863014    |
# | policy_loss        | -0.0016579509 |
# | serial_timesteps   | 26624         |
# | time_elapsed       | 18.6          |
# | total_timesteps    | 26624         |
# | value_loss         | 1.0785815     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.655903e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0424         |
# | fps                | 1554           |
# | n_updates          | 209            |
# | policy_entropy     | 0.12976147     |
# | policy_loss        | -0.00059471314 |
# | serial_timesteps   | 26752          |
# | time_elapsed       | 18.7           |
# | total_timesteps    | 26752          |
# | value_loss         | 1.0661229      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.8577162e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0938        |
# | fps                | 1536          |
# | n_updates          | 210           |
# | policy_entropy     | 0.12679681    |
# | policy_loss        | -0.0006897913 |
# | serial_timesteps   | 26880         |
# | time_elapsed       | 18.8          |
# | total_timesteps    | 26880         |
# | value_loss         | 1.0695951     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.9414764e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0691         |
# | fps                | 1535           |
# | n_updates          | 211            |
# | policy_entropy     | 0.13587922     |
# | policy_loss        | -0.00083054637 |
# | serial_timesteps   | 27008          |
# | time_elapsed       | 18.9           |
# | total_timesteps    | 27008          |
# | value_loss         | 1.0823644      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.1930395e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.118         |
# | fps                | 1507          |
# | n_updates          | 212           |
# | policy_entropy     | 0.12545565    |
# | policy_loss        | -0.0007601868 |
# | serial_timesteps   | 27136         |
# | time_elapsed       | 19            |
# | total_timesteps    | 27136         |
# | value_loss         | 0.83404946    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.4005896e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0593         |
# | fps                | 1290           |
# | n_updates          | 213            |
# | policy_entropy     | 0.15298691     |
# | policy_loss        | -0.00021324656 |
# | serial_timesteps   | 27264          |
# | time_elapsed       | 19.1           |
# | total_timesteps    | 27264          |
# | value_loss         | 1.3648714      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.897711e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0495       |
# | fps                | 1550          |
# | n_updates          | 214           |
# | policy_entropy     | 0.14199494    |
# | policy_loss        | -0.0009704004 |
# | serial_timesteps   | 27392         |
# | time_elapsed       | 19.2          |
# | total_timesteps    | 27392         |
# | value_loss         | 1.4935167     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.214353e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.14          |
# | fps                | 1537          |
# | n_updates          | 215           |
# | policy_entropy     | 0.13669488    |
# | policy_loss        | 5.2002724e-05 |
# | serial_timesteps   | 27520         |
# | time_elapsed       | 19.2          |
# | total_timesteps    | 27520         |
# | value_loss         | 1.0234307     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012890043 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0674        |
# | fps                | 1536          |
# | n_updates          | 216           |
# | policy_entropy     | 0.13517928    |
# | policy_loss        | -0.002710862  |
# | serial_timesteps   | 27648         |
# | time_elapsed       | 19.3          |
# | total_timesteps    | 27648         |
# | value_loss         | 1.0730956     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.3866061e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0682        |
# | fps                | 1499          |
# | n_updates          | 217           |
# | policy_entropy     | 0.1351852     |
# | policy_loss        | 0.0004719993  |
# | serial_timesteps   | 27776         |
# | time_elapsed       | 19.4          |
# | total_timesteps    | 27776         |
# | value_loss         | 1.3579443     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015372914 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0372        |
# | fps                | 1114          |
# | n_updates          | 218           |
# | policy_entropy     | 0.13390394    |
# | policy_loss        | -0.0011681071 |
# | serial_timesteps   | 27904         |
# | time_elapsed       | 19.5          |
# | total_timesteps    | 27904         |
# | value_loss         | 1.2452984     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024291042 |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.0871        |
# | fps                | 1296          |
# | n_updates          | 219           |
# | policy_entropy     | 0.11570867    |
# | policy_loss        | -0.0016204794 |
# | serial_timesteps   | 28032         |
# | time_elapsed       | 19.6          |
# | total_timesteps    | 28032         |
# | value_loss         | 1.3112123     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.0236453e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0359        |
# | fps                | 1266          |
# | n_updates          | 220           |
# | policy_entropy     | 0.115763955   |
# | policy_loss        | -0.0001255197 |
# | serial_timesteps   | 28160         |
# | time_elapsed       | 19.7          |
# | total_timesteps    | 28160         |
# | value_loss         | 1.4957128     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.721903e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0102        |
# | fps                | 1099           |
# | n_updates          | 221            |
# | policy_entropy     | 0.10653884     |
# | policy_loss        | -0.00021311635 |
# | serial_timesteps   | 28288          |
# | time_elapsed       | 19.8           |
# | total_timesteps    | 28288          |
# | value_loss         | 1.1961932      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00012531885 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.11          |
# | fps                | 1291          |
# | n_updates          | 222           |
# | policy_entropy     | 0.11013356    |
# | policy_loss        | -0.0030136628 |
# | serial_timesteps   | 28416         |
# | time_elapsed       | 19.9          |
# | total_timesteps    | 28416         |
# | value_loss         | 0.9462442     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00013361825  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.106          |
# | fps                | 1280           |
# | n_updates          | 223            |
# | policy_entropy     | 0.11955079     |
# | policy_loss        | -0.00093899353 |
# | serial_timesteps   | 28544          |
# | time_elapsed       | 20             |
# | total_timesteps    | 28544          |
# | value_loss         | 0.98323464     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.217259e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0985        |
# | fps                | 1257          |
# | n_updates          | 224           |
# | policy_entropy     | 0.101253875   |
# | policy_loss        | -0.0011776197 |
# | serial_timesteps   | 28672         |
# | time_elapsed       | 20.1          |
# | total_timesteps    | 28672         |
# | value_loss         | 0.89458966    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 1.181667e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0819       |
# | fps                | 1273         |
# | n_updates          | 225          |
# | policy_entropy     | 0.11483077   |
# | policy_loss        | 7.950654e-05 |
# | serial_timesteps   | 28800        |
# | time_elapsed       | 20.2         |
# | total_timesteps    | 28800        |
# | value_loss         | 0.9728575    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0002605974 |
# | clipfrac           | 0.005859375  |
# | explained_variance | 0.0477       |
# | fps                | 1275         |
# | n_updates          | 226          |
# | policy_entropy     | 0.11803711   |
# | policy_loss        | -0.002006684 |
# | serial_timesteps   | 28928        |
# | time_elapsed       | 20.3         |
# | total_timesteps    | 28928        |
# | value_loss         | 1.333767     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00027260836 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.116        |
# | fps                | 1114          |
# | n_updates          | 227           |
# | policy_entropy     | 0.11359438    |
# | policy_loss        | -0.0029098773 |
# | serial_timesteps   | 29056         |
# | time_elapsed       | 20.4          |
# | total_timesteps    | 29056         |
# | value_loss         | 1.3845178     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.116248e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.112          |
# | fps                | 1529           |
# | n_updates          | 228            |
# | policy_entropy     | 0.12264738     |
# | policy_loss        | -0.00068097026 |
# | serial_timesteps   | 29184          |
# | time_elapsed       | 20.5           |
# | total_timesteps    | 29184          |
# | value_loss         | 1.0569462      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0001414401  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.116         |
# | fps                | 1508          |
# | n_updates          | 229           |
# | policy_entropy     | 0.10175843    |
# | policy_loss        | -0.0021830152 |
# | serial_timesteps   | 29312         |
# | time_elapsed       | 20.6          |
# | total_timesteps    | 29312         |
# | value_loss         | 1.1367273     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.3012857e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0807         |
# | fps                | 1280           |
# | n_updates          | 230            |
# | policy_entropy     | 0.08812245     |
# | policy_loss        | -0.00054446235 |
# | serial_timesteps   | 29440          |
# | time_elapsed       | 20.7           |
# | total_timesteps    | 29440          |
# | value_loss         | 0.89974475     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.3942783e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0436         |
# | fps                | 1566           |
# | n_updates          | 231            |
# | policy_entropy     | 0.09839558     |
# | policy_loss        | -0.00043968752 |
# | serial_timesteps   | 29568          |
# | time_elapsed       | 20.8           |
# | total_timesteps    | 29568          |
# | value_loss         | 1.2151296      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 3.0751494e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.114          |
# | fps                | 1536           |
# | n_updates          | 232            |
# | policy_entropy     | 0.096149154    |
# | policy_loss        | -1.4014076e-06 |
# | serial_timesteps   | 29696          |
# | time_elapsed       | 20.9           |
# | total_timesteps    | 29696          |
# | value_loss         | 1.0255271      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 9.444006e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.101          |
# | fps                | 1536           |
# | n_updates          | 233            |
# | policy_entropy     | 0.09221946     |
# | policy_loss        | -0.00012618606 |
# | serial_timesteps   | 29824          |
# | time_elapsed       | 21             |
# | total_timesteps    | 29824          |
# | value_loss         | 1.131655       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00011163792 |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.122         |
# | fps                | 1536          |
# | n_updates          | 234           |
# | policy_entropy     | 0.089375585   |
# | policy_loss        | -0.0017526321 |
# | serial_timesteps   | 29952         |
# | time_elapsed       | 21.1          |
# | total_timesteps    | 29952         |
# | value_loss         | 1.0060815     |
# --------------------------------------

# %% [markdown]
# ###### Model 2: A2C

# %%
"""
a2c_model = PPO2(MlpPolicy, env, verbose=1)
a2c_model.learn(total_timesteps=30000)
"""
# Out:
# '\na2c_model = PPO2(MlpPolicy, env, verbose=1)\na2c_model.learn(total_timesteps=30000)\n'

# %% [markdown]
# ### Run simulation

# %%
# Reset environment for simulation
state = env.reset()
done = False

# Run simulation with model
while not done:
    action, _states = ppo_model.predict(state)
    state, reward, done, info = env.step(action)
    
    for i in info:
        print(i, info[i], end=" | ")
    print()
# Out:
# Steps left: 29 | Inventory: 12 | Action: 0 | Reward: 0.17 |
# Steps left: 28 | Inventory: 11 | Action: 0 | Reward: 0.08 |
# Steps left: 27 | Inventory: 10 | Action: 0 | Reward: 0.09 |
# Steps left: 26 | Inventory: 9 | Action: 0 | Reward: 0.1 |
# Steps left: 25 | Inventory: 8 | Action: 0 | Reward: 0.11 |
# Steps left: 24 | Inventory: 7 | Action: 0 | Reward: 0.12 |
# Steps left: 23 | Inventory: 6 | Action: 0 | Reward: 0.14 |
# Steps left: 22 | Inventory: 5 | Action: 1 | Reward: 0.17 |
# Steps left: 21 | Inventory: 4 | Action: 1 | Reward: 0.2 |
# Steps left: 20 | Inventory: 3 | Action: 1 | Reward: 0.25 |
# Steps left: 19 | Inventory: 2 | Action: 0 | Reward: 0.33 |
# Steps left: 18 | Inventory: 6 | Action: 0 | Reward: 0.5 |
# Steps left: 17 | Inventory: 10 | Action: 0 | Reward: 0.17 |
# Steps left: 16 | Inventory: 14 | Action: 0 | Reward: 0.1 |
# Steps left: 15 | Inventory: 13 | Action: 0 | Reward: 0.07 |
# Steps left: 14 | Inventory: 12 | Action: 0 | Reward: 0.08 |
# Steps left: 13 | Inventory: 11 | Action: 0 | Reward: 0.08 |
# Steps left: 12 | Inventory: 10 | Action: 0 | Reward: 0.09 |
# Steps left: 11 | Inventory: 9 | Action: 0 | Reward: 0.1 |
# Steps left: 10 | Inventory: 8 | Action: 0 | Reward: 0.11 |
# Steps left: 9 | Inventory: 7 | Action: 0 | Reward: 0.12 |
# Steps left: 8 | Inventory: 6 | Action: 0 | Reward: 0.14 |
# Steps left: 7 | Inventory: 5 | Action: 0 | Reward: 0.17 |
# Steps left: 6 | Inventory: 4 | Action: 1 | Reward: 0.2 |
# Steps left: 5 | Inventory: 3 | Action: 1 | Reward: 0.25 |
# Steps left: 4 | Inventory: 2 | Action: 0 | Reward: 0.33 |
# Steps left: 3 | Inventory: 1 | Action: 0 | Reward: 0.5 |
# Steps left: 2 | Inventory: 5 | Action: 0 | Reward: 1.0 |
# Steps left: 1 | Inventory: 9 | Action: 1 | Reward: 0.2 |
# Steps left: 0 | Inventory: 8 | Action: 0 | Reward: 0.11 |

# %%
"""
# Reset environment for simulation
state = env.reset()
done = False

# Run simulation with model
while not done:
    action, _states = a2c_model.predict(state)
    state, reward, done, info = env.step(action)
    print(info)
    # env.simulation.print_state()
"""
# Out:
# '\n# Reset environment for simulation\nstate = env.reset()\ndone = False\n\n# Run simulation with model\nwhile not done:\n    action, _states = a2c_model.predict(state)\n    state, reward, done, info = env.step(action)\n    print(info)\n    # env.simulation.print_state()\n'
